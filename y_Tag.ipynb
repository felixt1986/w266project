# %% [markdown]
# **US Public Listed Companies with focus on US Market
#
# Drugstores
# CVS Health Corporation [CVS]
# Rite Aid Corporation [RAD]
#
# Furniture
# Conn's Inc. [CONN]
#
#
# Grocery Stores
# Casey's General Stores Inc. [CASY]
# The Kroger Company [KR]
# SUPERVALU Inc. [SVU]
# Village Super Market Inc. [VLGEA]
# Weis Markets Inc. [WMK]
#
# Home Furnishings Stores
# Haverty Furniture Companies Inc. [HVT]
# Kirkland's Inc. [KIRK]
# Pier 1 Imports Inc. [PIR]
#
#
# Home Improvement Stores
# Builders FirstSource Inc. [BLDR]
# Huttig Building Products Inc. [HBP]
# Lumber Liquidators, Inc. [LL]
#
# Music and Video Retail
# Trans World Entertainment Corporation [TWMC]
#
# Specialty Retail
# Barnes & Noble Inc. [BKS]
# MarineMax Inc. [HZO]
#
# Medifast Inc. [MED]
# Office Depot Inc. [ODP]
# Sally Beauty Holdings Inc. [SBH]
# Sotheby's [BID]
# Star Gas Partners L.P. [SGU]
# Suburban Propane Partners L.P. [SPH]
# Titan Machinery Inc. [TITN]
# Tractor Supply Company [TSCO]
# TravelCenters of America LLC [TA]
# Vertical Branding Inc. [VBDG.OB]
#
# Sporting Goods Stores
# Big 5 Sporting Goods Corporation [BGFV]
# Dick's Sporting Goods Inc. [DKS]
# Hibbett Sports Inc. [HIBB]
#
# Toy and Hobby Stores
# Build-A-Bear Workshop Inc. [BBW]

# %%
l = [("CVS Health", "CVS"),("Rite Aid", "RAD"),
("Conn's", "CONN"),
("Casey's", "CASY"),
("Kroger", "KR"),
("SUPERVALU", "SVU"),
("Village Super Market", "VLGEA"),
("Weis Markets", "WMK"),
("Haverty Furniture", "HVT"),
("Kirkland's", "KIRK"),
("Pier 1 Imports","PIR"),
("Builders FirstSource","BLDR"),
("Huttig Building Products", "HBP"),
("Lumber Liquidators", "LL"),
("Trans World Entertainment", "TWMC"),
("Barnes & Noble", "BKS"),
("MarineMax", "HZO"),
("Medifast", "MED"),
("Sally Beauty Holdings", "SBH"),
("Sotheby's", "BID"),
("Star Gas Partners", "SGU"),
("Suburban Propane Partners", "SPH"),
("Titan Machinery", "TITN"),
("Tractor Supply","TSCO"),
("TravelCenters of America", "TA"),
("Big 5 Sporting Goods", "BGFV"),
("Dick's Sporting Goods", "DKS"),
("Hibbett Sports", "HIBB"),
("Build-A-Bear Workshop", "BBW")]
     
all_stock = {}
[all_stock.update({k:v}) for k,v in l]
print(all_stock)
#all_stock=['CVS','RAD','CONN','CASY','KR','SVU','VLGEA','WMK,HVT,KIRK, PIR,BLDR,HBP,LL,TWMC,HZO,MED,ODP,SBH,BID,SGU,SPH, TITN,TSCO, TA, BGFV,DKS, HIBB, BBW]
# Out:
# {'Weis Markets': 'WMK', 'Pier 1 Imports': 'PIR', "Kirkland's": 'KIRK', 'TravelCenters of America': 'TA', 'Build-A-Bear Workshop': 'BBW', 'Kroger': 'KR', 'Sally Beauty Holdings': 'SBH', 'MarineMax': 'HZO', 'Haverty Furniture': 'HVT', 'CVS Health': 'CVS', 'Lumber Liquidators': 'LL', "Dick's Sporting Goods": 'DKS', 'Builders FirstSource': 'BLDR', 'Village Super Market': 'VLGEA', 'Suburban Propane Partners': 'SPH', 'Huttig Building Products': 'HBP', 'Big 5 Sporting Goods': 'BGFV', 'Barnes & Noble': 'BKS', "Conn's": 'CONN', 'Medifast': 'MED', 'Star Gas Partners': 'SGU', 'Titan Machinery': 'TITN', 'Rite Aid': 'RAD', 'SUPERVALU': 'SVU', 'Tractor Supply': 'TSCO', "Casey's": 'CASY', "Sotheby's": 'BID', 'Hibbett Sports': 'HIBB', 'Trans World Entertainment': 'TWMC'}

# %%
import urllib.request, json 
from collections import defaultdict
import datetime as DT

# %%
top="http://datafied.api.edgar-online.com/v2/corefinancials/qtr?primarysymbols="
bottom="&appkey=asc97xrhkyu4959aptu76zxj"

# %%
Revenue_Table =defaultdict(dict)
for stock in all_stock.values():
    check=top+stock+bottom
    with urllib.request.urlopen(check) as url:
        data = json.loads(url.read().decode())
    count=0
    end_date=[]
    start_date=[]
    revenue_change=[]

    for key, value in data.items():
        for key2, value2 in value.items():
            for i in reversed(value2):
                for j in i["values"]:
                    if count!=0:   
                        if j["field"] =="periodenddate":
                            end_date.append(DT.datetime.strptime(j['value'], '%m/%d/%Y'))
                            start_date.append(DT.datetime.strptime(j['value'], '%m/%d/%Y')- DT.timedelta(days=90))
                    
                        if j["field"] =="totalrevenue":
                       
                            revenue_cal =float(j['value'])/float(last_rev)
                            revenue_change.append(revenue_cal)
                    
                    if j["field"] =="totalrevenue":
                            
                        last_rev=j['value']
                count+=1
            break      
    Revenue_Table[stock]["startdate"]=start_date
    Revenue_Table[stock]["enddate"]=end_date
    Revenue_Table[stock]["revenuechange"]=revenue_change

# %%
print(Revenue_Table)
# Out:
# defaultdict(<class 'dict'>, {'DKS': {'revenuechange': [1.4148433687589042, 0.7246776166362501, 1.1646136095899338, 0.9010674286428971, 1.3637003409782014, 0.7412076778609058, 1.1852111280620932, 0.9199586148790283, 1.3717994395549582, 0.7349713078629462, 1.1817058685595194, 0.9013756246780698, 1.3703013136082074, 0.7168286587476099, 1.1402138220335034], 'enddate': [datetime.datetime(2015, 1, 31, 0, 0), datetime.datetime(2015, 5, 2, 0, 0), datetime.datetime(2015, 8, 1, 0, 0), datetime.datetime(2015, 10, 31, 0, 0), datetime.datetime(2016, 1, 30, 0, 0), datetime.datetime(2016, 4, 30, 0, 0), datetime.datetime(2016, 7, 30, 0, 0), datetime.datetime(2016, 10, 29, 0, 0), datetime.datetime(2017, 1, 28, 0, 0), datetime.datetime(2017, 4, 29, 0, 0), datetime.datetime(2017, 7, 29, 0, 0), datetime.datetime(2017, 10, 28, 0, 0), datetime.datetime(2018, 2, 3, 0, 0), datetime.datetime(2018, 5, 5, 0, 0), datetime.datetime(2018, 8, 4, 0, 0)], 'startdate': [datetime.datetime(2014, 11, 2, 0, 0), datetime.datetime(2015, 2, 1, 0, 0), datetime.datetime(2015, 5, 3, 0, 0), datetime.datetime(2015, 8, 2, 0, 0), datetime.datetime(2015, 11, 1, 0, 0), datetime.datetime(2016, 1, 31, 0, 0), datetime.datetime(2016, 5, 1, 0, 0), datetime.datetime(2016, 7, 31, 0, 0), datetime.datetime(2016, 10, 30, 0, 0), datetime.datetime(2017, 1, 29, 0, 0), datetime.datetime(2017, 4, 30, 0, 0), datetime.datetime(2017, 7, 30, 0, 0), datetime.datetime(2017, 11, 5, 0, 0), datetime.datetime(2018, 2, 4, 0, 0), datetime.datetime(2018, 5, 6, 0, 0)]}, 'HZO': {'revenuechange': [1.0886444986909174, 1.346839546191248, 0.8162726602228174, 0.8958267283833196, 1.1771235777440912, 1.7317178276860787, 0.6578711312761869, 0.9978887642673352, 1.0799691460055096, 1.3460602894481222, 0.7598882989851702, 0.9453471019639451, 1.1421739736030154, 1.3349864193196725, 0.8542216833585233], 'enddate': [datetime.datetime(2015, 3, 31, 0, 0), datetime.datetime(2015, 6, 30, 0, 0), datetime.datetime(2015, 9, 30, 0, 0), datetime.datetime(2015, 12, 31, 0, 0), datetime.datetime(2016, 3, 31, 0, 0), datetime.datetime(2016, 6, 30, 0, 0), datetime.datetime(2016, 9, 30, 0, 0), datetime.datetime(2016, 12, 31, 0, 0), datetime.datetime(2017, 3, 31, 0, 0), datetime.datetime(2017, 6, 30, 0, 0), datetime.datetime(2017, 9, 30, 0, 0), datetime.datetime(2017, 12, 31, 0, 0), datetime.datetime(2018, 3, 31, 0, 0), datetime.datetime(2018, 6, 30, 0, 0), datetime.datetime(2018, 9, 30, 0, 0)], 'startdate': [datetime.datetime(2014, 12, 31, 0, 0), datetime.datetime(2015, 4, 1, 0, 0), datetime.datetime(2015, 7, 2, 0, 0), datetime.datetime(2015, 10, 2, 0, 0), datetime.datetime(2016, 1, 1, 0, 0), datetime.datetime(2016, 4, 1, 0, 0), datetime.datetime(2016, 7, 2, 0, 0), datetime.datetime(2016, 10, 2, 0, 0), datetime.datetime(2016, 12, 31, 0, 0), datetime.datetime(2017, 4, 1, 0, 0), datetime.datetime(2017, 7, 2, 0, 0), datetime.datetime(2017, 10, 2, 0, 0), datetime.datetime(2017, 12, 31, 0, 0), datetime.datetime(2018, 4, 1, 0, 0), datetime.datetime(2018, 7, 2, 0, 0)]}, 'VLGEA': {'revenuechange': [1.0828110516558525, 0.9414116554107459, 1.0481890984241797, 0.9600127170650197, 1.0786616657553096, 0.9232096532355951, 1.1273404570706744, 0.8911299082325447, 1.0577969268037322, 0.9509212425554625, 1.047703477692967, 0.9410518575154072, 1.0799743320378603, 0.9454360753458463, 1.0480046020354377], 'enddate': [datetime.datetime(2015, 1, 24, 0, 0), datetime.datetime(2015, 4, 25, 0, 0), datetime.datetime(2015, 7, 25, 0, 0), datetime.datetime(2015, 10, 24, 0, 0), datetime.datetime(2016, 1, 23, 0, 0), datetime.datetime(2016, 4, 23, 0, 0), datetime.datetime(2016, 7, 30, 0, 0), datetime.datetime(2016, 10, 29, 0, 0), datetime.datetime(2017, 1, 28, 0, 0), datetime.datetime(2017, 4, 29, 0, 0), datetime.datetime(2017, 7, 29, 0, 0), datetime.datetime(2017, 10, 28, 0, 0), datetime.datetime(2018, 1, 27, 0, 0), datetime.datetime(2018, 4, 28, 0, 0), datetime.datetime(2018, 7, 28, 0, 0)], 'startdate': [datetime.datetime(2014, 10, 26, 0, 0), datetime.datetime(2015, ...
